# %%
print('hello world')
# Out:
# hello world

# %%
customer_id = 1
customer_name = 'Oscar Ramos'
customer_gender = 'M'
customer_dob = '19-10-1999'
driver_license = 'A123456789'
auto_policy = '123-456-7891'

# %%
print(customer_name)
# Out:
# Oscar Ramos
