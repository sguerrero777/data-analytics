# %% [markdown]
# # Data Analysis Notes - Demo 1

# %% [markdown]
# ## Goals
# - Clean Data
# - Analyze Trends
# - Build Models

# %% [markdown]
# ### Sample Code

# %%
'''Python'''
x = 10
y = 20
print (x + y)
# Out:
# 30
