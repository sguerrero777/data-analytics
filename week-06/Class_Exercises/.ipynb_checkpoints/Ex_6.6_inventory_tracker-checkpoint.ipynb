# %% [markdown]
# # Product Inventory Tracker
#
# **Course:** Data Analytics | **Date:** 5/18/2026
#
# You are a data analyst at StockSmart Inc. Your manager wants a script that models a
# product using a `class`, lets a warehouse associate enter two products via input(), and displays a formatted report for each product using two method.

# %%
# Defining the class
class Product:
    ''' This class contains product information and accessible tracking
     methods for warehouse employees.'''

    # Initializing attributes, no real data yet
    def __init__(self, name , category, price, quantity):
        self.name = name
        self.category = category
        self.price = price
        self.quantity = quantity
        
    # Method for Displaying Product Information
    def display_info(self):
        print(f"Product Name : {self.name}")
        print(f"Category : {self.category}")
        print(f"Price : ${self.price:.2f}")
        print(f"Quantity : {self.quantity} units")
        print("-----------------------------")

    # Method 2 Calculate Inventory Value
    def inventory_value(self):
        value = self.price * self.quantity
        print(f" Toral Inventory value for {self.name}: ${value:.2f}")
        print("-----------------------------")

# Create 2 product objects with User Input
print("--- Enter Product 1 ---")
name1 = input("Product name: ")
category1 = input("Category: ")
price1 = float (input("Price $: "))
quantity1 = int (input("Quantity: "))

print("\n--- Enter Product 2 ---")
name2 = input("Product name: ")
category2 = input("Category: ")
price2 = float (input("Price $: "))
quantity2 = int (input("Quantity: "))
product1 = Product(name1, category1, price1, quantity1)
product2 = Product(name2, category2, price2, quantity2)

# Calling Methods 
print("\n===== Product 1: " + product1.name + " =====")
print(f"Product 1: {product1.name} {product1.category}")
product1.display_info()
product1.inventory_value()

print("===== Product 2: " + product2.name + " =====")
print(f"Product 2: {product2.name} {product2.category}")
product2.display_info()
product2.inventory_value()
# Out:
# --- Enter Product 1 ---
# Product name:  Keyboard
# Category:  Electronics
# Price $:  85.99
# Quantity:  150
# --- Enter Product 2 ---
# Product name:  Monitor
# Category:  Electronics
# Price $:  199.99
# Quantity:  100
# ===== Product 1: Keyboard =====
# Product 1: Keyboard Electronics
# Product Name : Keyboard
# Category : Electronics
# Price : $85.99
# Quantity : 150 units
# -----------------------------
#  Toral Inventory value for Keyboard: $12898.50
# -----------------------------
# ===== Product 2: Monitor  =====
# Product 2: Monitor  Electronics
# Product Name : Monitor
# Category : Electronics
# Price : $199.99
# Quantity : 100 units
# -----------------------------
#  Toral Inventory value for Monitor : $19999.00
# -----------------------------
