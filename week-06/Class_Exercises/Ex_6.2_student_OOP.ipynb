# %% [markdown]
# # YearUp Academy - Student Roster Manager
# **Course:** Data Analytics | **Date:** 5/14/2026
#
# This notebook uses an `object-oriented program` that models a student using a **class** with **encapsulation**, keeping the grade private and only accessible through controlled getter and setter methods.

# %%
#Defining a class named Student with the shared Class Attribute "school"
class Student:
    school = "YearUp Academy"
